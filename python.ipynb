# %% [markdown]
# <a href="https://colab.research.google.com/github/Nazmusjion1/Alpha-class-game/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hello')
# Out:
# hello

# %%
2+32
# Out:
# 34
